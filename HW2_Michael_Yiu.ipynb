# %% [markdown]
# # Homework 2
# ### DSCI 510 / USC / Hermjakob section / Spring 2025
#
# Hello and welcome to HW2.
#
# Guidelines:
#
# Please write and submit the programs and data files below by the deadline: Friday, March 28, at 6:00pm Pacific time
#
# You must complete the assignments individually. If you have trouble completing the assignment, please let one of the teaching assistants (TAs) know, during the lab or their office hours. They will help and guide you, but they will not write code for you and no one else should :) !!!
#
# The submission will include several components. Submissions to HW2 will contain **3** files:
# * HW2_[YOUR FIRSTNAME]_[YOUR LASTNAME].ipynb (for all your code)
# * HW2_[YOUR FIRSTNAME]_[YOUR LASTNAME]_airports.tsv (result of Q2)
# * HW2_[YOUR FIRSTNAME]_[YOUR LASTNAME]_airport-coordinates.tsv (result of Q3)
#
# You may look up resources online like python docs and stackoverflow. You may look up topics, but not the questions themselves.
#
# You can submit only one time. Your grade will be based on this submission.
#
# This Homework2 requires a substantial amount of work. You can almost certainly **not** do it in a single day, so please start early.

# %% [markdown]
# # Q1 [20 points]
#
# ### Country population data
#
# **Python topics:** BeautifulSoup, requests, dictionaries
#
# The task is about extracting relevant population data from a Wikipedia table into a Python dictionary.
#
# Write the function __load_population_dict__ to load the content of https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population into a dictionary,
# using the country as a key, and the tuple (population_count, population_percentage) as a value.
#
# Strategy
# * Use the _requests_ library to read the content of the data file on the internet.
# * Use the _BeautifulSoup_ library to first __parse__ the content you downloaded into a _soup_ object.
# * Use the _BeautifulSoup_ library to navigate the _soup_ object and extract the info you need.
#
# Tips
# - One way to gain a quick overview if the content of an HTML webpage is to visit it in a browser (such as Chrome) and inspect the HTML code on that page through "View Page Source" or similar.
#
# - Note that the HTML file contains several tables, of which only one is of interest to us; one way to find the correct table is to check its caption for tell-tale signs.
#
# FAQs: <br>
# Q. How to read/parse a website?
# A. For that, as taught in class you would need to use libraries like BeautifulSoup and requests.
#
# Q. I don't know html, what should I do?
# A. No worries. For this lab, you only need to understand that html is another type of a language made up of tags. For example, it has heading info in the *head* tag, paragraph has *p* tag, and html links have *a* tag. So, using the tag, you can get the info you need!
#
# Q. How do I get the tag info?
# A. When you get your BeautifulSoup object you can do something like object.find_all('tag') or object('tag') to get all 'tag' tags.
#
# Q. What are tag attributes and how can I access that?
# A. HTML attributes are special words used inside the tag to control the element's behaviour. One can access attributes using the *get* function.
#
# Q. I got the tag, but what I got seems cryptic. What now?
# A. So, once you get the info from a particular tag, you get the whole html code inside that tag. If you want some particular information from that, you would need to call functions like _get_ and _get_text_ to get the information directly without messing with the html code.
#
# Q. What if the number of `<td>` elements inside a `<tr>` varies from row to row?<br>
# A. This might be due to some `<td>` element being shared between multiple rows or for other reasons. To address this, you can include checks on the number of `<td>` elements inside a `<tr>` and/or use a `<td>` with a recognizable pattern (of its text, of an attribute, or of a sub-element) as a reference point.
#
# Q. I am not sure how to use these functions. Help?
# A. You can read from the official documentation and study the examples that we have been providing.
# * Documentation link: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
# * Study the BeautifulSoup section in https://www.isi.edu/~ulf/teaching/python.html
# * Study the examples in week9-1_Requests.ipynb (Blackboard -> Lectures -> Notebook section)
#
# Good Feature: Use the .prettify() feature of BeautifulSoup. You'll get a better insight of what is that you are scrapping. See example below.
#
# Before you begin, make sure you have _BeautifulSoup_ installed:
# ```
# pip install bs4
# ```

# %%
# Example for .prettify().  Applicable to full HTML text or parts thereof.
from bs4 import BeautifulSoup
s = '<tr><td><a href="https://www.france.fr">France</a></td><td cat="capital city" pop="2,102,650">Paris</td></tr>'
table_row = BeautifulSoup(s, 'html.parser')
print(table_row.prettify())
# Out:
# <tr>
#  <td>
#   <a href="https://www.france.fr">
#    France
#   </a>
#  </td>
#  <td cat="capital city" pop="2,102,650">
#   Paris
#  </td>
# </tr>

# %%
import requests
from bs4 import BeautifulSoup

def load_population_dict(url: str) -> dict:
    html = requests.get(url).text
    if soup := BeautifulSoup(html,'html.parser'):
        table = soup.find('table')
        headers = []
        countries_dict = dict()
        
        for th in table.find('tr').find_all('th'):
            headers.append(th.text.strip())

        location_index = headers.index('Location')
        pop_index = headers.index('Population')
        percent_index = headers.index('% ofworld')

        for row in table.find_all('tr'):
            data =  row.find_all('td')
            if len(data) > percent_index:
                country = data[location_index].text.strip()
                population = data[pop_index].text.strip()
                percent = data[percent_index].text.strip()
                countries_dict[country] = (population,percent)
            
        return countries_dict

# %%
# open test
def print_population_info(country: str, population_dict: dict) -> str:
    if pop_tuple := population_dict.get(country, None):
        pop_count, pop_percent = pop_tuple
        print(f'{country} has a population of {pop_count}, which is {pop_percent} of the world population.')
    else:
        print(f'Sorry, no info available for {country}.')
       
pop_dict = load_population_dict("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population")
print(f'Loaded {len(pop_dict)} entries.')
for country in ['Australia', 'Brazil', 'China', 'England', 'India', 'Liechtenstein', 'Vietnam']:
    print_population_info(country, pop_dict)
# Out:
# Loaded 240 entries.
# Australia has a population of 27,309,396, which is 0.3% of the world population.
# Brazil has a population of 212,583,750, which is 2.6% of the world population.
# China has a population of 1,408,280,000, which is 17.2% of the world population.
# Sorry, no info available for England.
# India has a population of 1,413,324,000, which is 17.3% of the world population.
# Liechtenstein has a population of 40,900, which is 0.0005% of the world population.
# Vietnam has a population of 101,343,800, which is 1.2% of the world population.

# %% [markdown]
# # Q2 [20 points]
#
# ### Overview Q2-Q5
#
# The remaining questions (Q2-Q5) will guide you to build a simple __Airport Information System (AIS)__.
# * Build a file airports.tsv with basic airport info, scraped from Wikipedia. (Q2)
# * Build a file airport-coordinates.tsv with airport geo-coordinates, also scraped from Wikipedia. (Q3)
# * Define a GeoCoordinates class and functions that convert between DMS and plain latitude/longitude format. (Q4)
# * Define Airport and GeoAirport classes and write a Python program to answer the type of queries below. (Q5)
#    * show airport info given an airport's IATA code
#    * show airport info given part of an airport's name
#    * show nearest airport(s) given geo-coordinates in either format
# * Libraries/tools/examples for Q2 and Q3
#     * To download a file from the internet, use the *requests* library.
#     * To extract information from a downloaded HTML file, use *BeautifulSoup*.
#     * For examples, see *week9-1_Requests.ipynb* and *week9-1_BeautifulSoup.ipynb* (on Brightspace -> lectures)
#
# ### Q2
#
# Wikipedia lists airports at https://en.wikipedia.org/wiki/List_of_airports_by_IATA_airport_code:_A
# through https://en.wikipedia.org/wiki/List_of_airports_by_IATA_airport_code:_Z .
#
# Write code that scrapes core airport info from those 26 Wikipedia pages:
# (1) IATA code, (2) name, (3) location, (4) URL,<br>
# creating a file __airports.tsv__ with the 4 fields separated by tab (not comma). E.g.
# ```
# AAA	Anaa Airport	Anaa, Tuamotus, French Polynesia	https://en.wikipedia.org/wiki/Anaa_Airport
# AAB	Arrabury Airport	Arrabury, Queensland, Australia	https://en.wikipedia.org/wiki/Arrabury_Airport
# AAC	El Arish International Airport	El Arish, Egypt	https://en.wikipedia.org/wiki/El_Arish_International_Airport
# ...
# ```
# We recommend that you first download the 26 Wikipedia webpages to files on your computer (caching),
# and then extract the relevant data from those cached files. This avoids you having to download the same files from
# the Web several times as you develop and test your extraction code.
# To further avoid bursts of requests, you might want to space out your requests
# by "sleeping" (waiting) for a few seconds between requests.
#
# Make sure to excludes footnotes such as "[1]" from IATA codes etc.<br>
# IATA codes should be coomposed of three uppercase ASCII letters [A-Z].<br>
# You will need the URLs to look up geo-coordinates for Californian airports in Q3.

# %%
import time
import requests
from bs4 import BeautifulSoup
import csv

wiki_pages = []
alphabet = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
alphabet = 'A'
for letter in alphabet:
    link = f'https://en.wikipedia.org/wiki/List_of_airports_by_IATA_airport_code:_{letter}'
    wiki_pages.append(link)

for url in wiki_pages:    
    html = requests.get(url).text
    #time.sleep(.05)
    if soup := BeautifulSoup(html,'html.parser'):
        table = soup.find('table')
        headers = []
        for header in table.find_all('th'):
            header = header.text.strip().replace('\xa0',' ')
            headers.append(header)
        
        headers = headers[:6]

        for row in table.find_all('tr'):
            links = row.find_all('a')
            if len(links) > 0:
                print(links[0].get('href'))
# Out:
# /wiki/IATA
# /wiki/Anaa_Airport
# /wiki/Arrabury_Airport
# /wiki/El_Arish_International_Airport
# /wiki/Adado_Airport
# /wiki/Rabah_Bitat_Airport
# /wiki/Apalachicola_Regional_Airport
# /wiki/Arapoti_Airport
# /wiki/Merzbr%C3%BCck_Airport
# /wiki/Arraias_Airport
# /wiki/Cayana_Airstrip
# /wiki/Aranuka_Airport
# /wiki/Aalborg_Airport
# /wiki/Mala_Mala_Airport
# /wiki/Al_Ain_International_Airport
# /wiki/Anaco_Airport
# /wiki/Aji_Pangeran_Tumenggung_Pranoto_International_Airport
# /wiki/Anapa_Airport
# /wiki/Aarhus_Airport
# /wiki/Apalapsili_Airport
# /wiki/Altay_Airport
# /wiki/Asau_Airport
# /wiki/Allah_Valley_Airport
# /wiki/Arax%C3%A1_Airport
# /wiki/Al_Ghaydah_Airport
# /wiki/Quetzaltenango_Airport
# /wiki/Abakan_International_Airport
# /wiki/Asaba_International_Airport
# /wiki/Albacete_Airport
# /wiki/Abadan_International_Airport
# /wiki/Lehigh_Valley_International_Airport
# /wiki/Abaiang_Atoll_Airport
# /wiki/Abingdon_Airport
# /wiki/Alpha_Airport
# /wiki/Abilene_Regional_Airport
# /wiki/Port_Bouet_Airport
# /wiki/Kabri_Dar_Airport
# /wiki/Ambler_Airport
# /wiki/Northern_Peninsula_Airport
# /wiki/Albina_Airstrip
# /wiki/Aboisso_Airport
# /wiki/Atkamba_Airport
# /wiki/Albuquerque_International_Sunport
# /wiki/Aberdeen_Regional_Airport
# /wiki/Abu_Simbel_Airport
# /wiki/Al-Baha_Domestic_Airport
# /wiki/Haliwen_Airport
# /wiki/Nnamdi_Azikiwe_International_Airport
# /wiki/Abau_Airport
# /wiki/Albury_Airport
# /wiki/Southwest_Georgia_Regional_Airport
# /wiki/Aberdeen_Airport
# /wiki/Acapulco_International_Airport
# /wiki/Antrim_County_Airport
# /wiki/Kotoka_International_Airport
# /wiki/Alcides_Fern%C3%A1ndez_Airport
# /wiki/Lanzarote_Airport
# /wiki/Aral_Talim_Airport
# /wiki/St._Gallen%E2%80%93Altenrhein_Airport
# /wiki/Alderney_Airport
# /wiki/Anuradhapura_Airport
# /wiki/Nantucket_Memorial_Airport
# /wiki/Aguaclara_Airport
# /wiki/Arica_Airport_(Colombia)
# /wiki/Ciudad_Acu%C3%B1a_International_Airport
# /wiki/Cobano_Airport
# /wiki/Sahand_Airport
# /wiki/Araracuara_Airport
# /wiki/Achinsk_Airport
# /wiki/Waco_Regional_Airport
# /wiki/Achutupo_Airport
# /wiki/Arcata-Eureka_Airport
# /wiki/Xingyi_Wanfenglin_Airport
# /wiki/Atlantic_City_International_Airport
# /wiki/Zabol_Airport
# /wiki/Adana_%C5%9Eakirpa%C5%9Fa_Airport
# /wiki/Adnan_Menderes_Airport
# /wiki/Andakombe_Airport
# /wiki/Bole_International_Airport
# /wiki/Aden_International_Airport
# /wiki/Ad%C4%B1yaman_Airport
# /wiki/Lenawee_County_Airport
# /wiki/Aldan_Airport
# /wiki/Arandis_Airport
# /wiki/Amman_Civil_Airport
# /wiki/Adak_Airport
# /wiki/Adelaide_Airport
# /wiki/Ardmore_Municipal_Airport
# /wiki/Andes_Airport
# /wiki/Andamooka_Airport
# /wiki/Ampara_Airport
# /wiki/Kodiak_Airport
# /wiki/Robert_F._Swinnie_Airport
# /wiki/Addison_Airport
# /wiki/Ada_Municipal_Airport
# /wiki/Ardabil_Airport
# /wiki/Ed_Daein_Airport
# /wiki/Andrews_Field
# /wiki/Leuchars_Station
# /wiki/Alldays_Airport
# /wiki/Gustavo_Rojas_Pinilla_International_Airport
# /wiki/Abemama_Atoll_Airport
# /wiki/Baise_Bama_Airport
# /wiki/Adareil_Airport
# /wiki/Aek_Godang_Airport
# /wiki/Ab%C3%A9ch%C3%A9_Airport
# /wiki/Aseki_Airport
# /wiki/Albert_Lea_Municipal_Airport
# /wiki/Amgu_Airport
# /wiki/Aioun_el_Atrouss_Airport
# /wiki/Jorge_Newbery_Airpark
# /wiki/Ar_Horqin_Airport
# /wiki/Sochi_International_Airport
# /wiki/%C3%85lesund_Airport,_Vigra
# /wiki/Allakaket_Airport
# /wiki/Abu_Musa_Airport
# /wiki/Alexandria_International_Airport_(Louisiana)
# /wiki/Akureyri_Airport
# /wiki/San_Rafael_Airport_(Argentina)
# /wiki/Port_Alfred_Airport
# /wiki/United_States_Air_Force_Academy_Airfield
# /wiki/Amalfi_Airport_(Colombia)
# /w/index.php?title=Kondavattavan_Tank_Seaplane_Base&action=edit&redlink=1
# /wiki/Alta_Floresta_Airport
# /wiki/Jaffrey_Airport%E2%80%93Silver_Ranch
# /wiki/Afton_Municipal_Airport
# /wiki/Afore_Airstrip
# /wiki/Zarafshan_Airport
# /wiki/Afutara_Airport
# /wiki/Fort_Worth_Alliance_Airport
# /wiki/Afyon_Airport
# /wiki/Sabzevar_Airport
# /wiki/Agadir%E2%80%93Al_Massira_Airport
# /wiki/Augsburg_Airport
# /wiki/Allegheny_County_Airport
# /wiki/Anggi_Airport
# /wiki/Wangerooge_Airfield
# /wiki/Agen_La_Garenne_Airport
# /w/index.php?title=Angoram_Airport&action=edit&redlink=1
# /wiki/%C3%84ngelholm%E2%80%93Helsingborg_Airport
# /wiki/Wageningen_Airstrip
# /wiki/Aguni_Airport
# /w/index.php?title=Kagua_Airport&action=edit&redlink=1
# /wiki/Wanigela_Airport
# /wiki/Angoon_Seaplane_Base
# /wiki/Magnolia_Municipal_Airport
# /wiki/M%C3%A1laga_Airport
# /wiki/Agrinion_Airport
# /wiki/Agra_Airport
# /wiki/Augusta_Regional_Airport
# /wiki/Guaran%C3%AD_International_Airport
# /wiki/Lic._Jes%C3%BAs_Ter%C3%A1n_Peredo_International_Airport
# /wiki/Oswaldo_Guevara_Mujica_Airport
# /wiki/Agnew_Airport
# /wiki/Agatti_Aerodrome
# /wiki/Aggeneys_Airport
# /wiki/Abha_Regional_Airport
# /wiki/Amedee_Army_Airfield
# /wiki/Ardmore_Downtown_Executive_Airport
# /wiki/Ahe_Airport
# /wiki/Arapahoe_Municipal_Airport
# /wiki/Amery_Municipal_Airport
# /wiki/Amahai_Airport
# /wiki/Hongyuan_Airport
# /wiki/Aishalton_Airport
# /wiki/Ashland_Municipal_Airport
# /wiki/Athens_Ben_Epps_Airport
# /wiki/Alghero-Fertilia_Airport
# /wiki/Ahuas_Airport
# /wiki/Cherif_Al_Idrissi_Airport
# /w/index.php?title=Saih_Rawl_Airport&action=edit&redlink=1
# /w/index.php?title=Ambatolahy_Airport&action=edit&redlink=1
# /wiki/Alpe_d%27Huez_Airport
# /wiki/Alliance_Municipal_Airport
# /wiki/Ailinglaplap_Airok_Airport
# /wiki/Anderson_Municipal_Airport
# /wiki/Aiome_Airport
# /wiki/Assis_Airport
# /wiki/Yalinga_Airport
# /wiki/Aiambak_Airport
# /wiki/Ali-Sabieh_Airport
# /wiki/Aiken_Municipal_Airport
# /wiki/Ailigand%C3%AD_Airport
# /wiki/Ailuk_Airport
# /wiki/Wainwright_Airport_(Alaska)
# /wiki/Atlantic_Municipal_Airport
# /wiki/Adampur_Airport
# /wiki/Aripuan%C3%A3_Airport
# /wiki/Arorae_Island_Airport
# /wiki/Aitutaki_Airport
# /wiki/Enua_Airport
# /wiki/George_Downer_Airport
# /w/index.php?title=Ai-Ais_Airport&action=edit&redlink=1
# /w/index.php?title=Ara%C3%A7uai_Airport&action=edit&redlink=1
# /wiki/Lee_C._Fine_Memorial_Airport
# /wiki/Ajaccio_Napoleon_Bonaparte_Airport
# /wiki/Al-Jawf_Domestic_Airport
# /wiki/A%C4%9Fr%C4%B1_Airport
# /wiki/Akjoujt_Airport
# /wiki/Arak_Airport
# #cite_note-2
# /wiki/Ouani_Airport
# /wiki/Arvidsjaur_Airport
# /wiki/Punta_Abreojos_Airstrip
# /wiki/Santa_Maria_Airport_(Sergipe)
# /wiki/Mano_Dayak_International_Airport
# /wiki/Ankang_Wulipu_Airport
# /wiki/Atka_Airport
# /wiki/Akron_Fulton_International_Airport
# /wiki/Akola_Airport
# /wiki/Akieni_Airport
# /wiki/Kufra_Airport
# /wiki/Papua_New_Guinea
# /wiki/Prince_Sultan_Air_Base
# /wiki/Akiak_Airport
# /wiki/Asahikawa_Airport
# /wiki/Akhiok_Airport
# /wiki/Auckland_Airport
# /wiki/Zakouma_Airport
# /wiki/King_Salmon_Airport
# /wiki/Colorado_Plains_Regional_Airport
# /wiki/Anaktuvuk_Pass_Airport
# /wiki/Gunung_Batin_Airport
# /wiki/Akure_Airport
# /wiki/Auki_Gwaunaru%27u_Airport
# /wiki/RAF_Akrotiri
# /wiki/Aksu_Airport
# /wiki/Akulivik_Airport
# /wiki/Aghajari_Airport
# /wiki/Aktobe_Airport
# /wiki/Sittwe_Airport
# /wiki/Almaty_International_Airport
# /wiki/Albany_International_Airport
# /wiki/Alicante%E2%80%93Elche_Airport
# /wiki/Alerta_Airport
# /wiki/Alpine%E2%80%93Casparis_Municipal_Airport
# /wiki/Alta_Airport
# /wiki/Houari_Boumediene_Airport
# /wiki/Albany_Airport_(Western_Australia)
# /wiki/Alice_International_Airport
# /wiki/Alexander_Bay_Airport
# /wiki/Asella
# /wiki/Albenga_Airport
# /wiki/Alamogordo%E2%80%93White_Sands_Regional_Airport
# /wiki/St._Louis_Regional_Airport
# /wiki/Waterloo_Regional_Airport
# /wiki/Aleppo_International_Airport
# /wiki/Alegrete_Airport
# /wiki/Alexandra_Aerodrome
# /wiki/San_Luis_Valley_Regional_Airport
# /wiki/Alenquer_Airport
# /wiki/Alula_Airport
# /wiki/Walla_Walla_Regional_Airport
# /wiki/Thomas_C._Russell_Field
# /wiki/El_Nouzha_Airport
# /wiki/Alitak_Seaplane_Base
# /wiki/Rick_Husband_Amarillo_International_Airport
# /wiki/Ambilobe_Airport
# /wiki/Am_Timan_Airport
# /wiki/Sardar_Vallabhbhai_Patel_International_Airport
# /wiki/Mozambique
# /wiki/Papua_New_Guinea
# /wiki/Papua_New_Guinea
# /wiki/Arba_Minch_Airport
# /wiki/Selaparang_Airport
# /wiki/Almenara,_Minas_Gerais
# /wiki/Animas_Air_Park
# /wiki/Puerto_Armuelles
# /wiki/Queen_Alia_International_Airport
# /wiki/Gratiot_Community_Airport
# /wiki/Mao_Airport
# /wiki/Ampanihy_Airport
# /wiki/Pattimura_Airport
# /wiki/Amsterdam_Airport_Schiphol
# /wiki/Amata_Airport
# /wiki/Papua_New_Guinea
# /wiki/Amderma_Airport
# /wiki/Ames_Municipal_Airport
# /wiki/Northern_Territory
# /wiki/Ambatomainty_Airport
# /wiki/Ardmore_Airport_(New_Zealand)
# /wiki/Angama_Mara_Airport
# /wiki/Anniston_Regional_Airport
# /wiki/Ted_Stevens_Anchorage_International_Airport
# /wiki/Anderson_Regional_Airport
# /wiki/Angers_%E2%80%93_Loire_Airport
# /wiki/Cerro_Moreno_International_Airport
# /wiki/Angoul%C3%AAme_%E2%80%93_Cognac_International_Airport
# /wiki/Aniak_Airport
# /wiki/Zanaga_Airport
# /wiki/Etimesgut_Air_Base
# /wiki/Andulo_Airport
# /wiki/Antsirabato_Airport
# /wiki/Annette_Island_Airport
# /wiki/Angoche_Airport
# /wiki/Lee_Airport
# /wiki/Tri-State_Steuben_County_Airport
# /wiki/Antwerp_International_Airport
# /wiki/Andahuaylas_Airport
# /wiki/V._C._Bird_International_Airport
# /wiki/Anvik_Airport
# /wiki/Ainsworth_Regional_Airport
# /wiki/And%C3%B8ya_Airport,_Andenes
# /wiki/Anthony_Municipal_Airport
# /wiki/Northern_Territory
# /wiki/Papua_New_Guinea
# /wiki/Papua_New_Guinea
# /wiki/Leipzig%E2%80%93Altenburg_Airport
# /wiki/Abou-De%C3%AFa_Airport
# /wiki/Anadolu_Airport
# /wiki/Anshan_Teng%27ao_Airport
# /wiki/Lima_Allen_County_Airport
# /wiki/Ancona_Falconara_Airport
# /wiki/Aomori_Airport
# /wiki/Karpathos_Island_National_Airport
# /wiki/Paso_de_los_Libres_Airport
# /wiki/Adam_Airport
# /wiki/Papua_New_Guinea
# /wiki/Altoona%E2%80%93Blair_County_Airport
# /wiki/Alf%C3%A9rez_FAP_Alfredo_Vladimir_Sara_Bauer_Airport
# /wiki/Sultan_Abdul_Halim_Airport
# /wiki/Amook_Bay_Seaplane_Base
# /wiki/Aosta_Valley_Airport
# /wiki/Attapeu_International_Airport
# /wiki/Centennial_Airport
# /wiki/Apolo_Airport
# /wiki/Napa_County_Airport
# /wiki/Naples_Municipal_Airport
# /wiki/Phillips_Army_Airfield
# /wiki/A.P._Hill_Army_Airfield
# /wiki/Captain_Luis_F._G%C3%B3mez_Ni%C3%B1o_Air_Base
# /wiki/Apataki_Airport
# /wiki/Nampula_Airport
# /wiki/Alpena_County_Regional_Airport
# /wiki/Antonio_Rold%C3%A1n_Betancourt_Airport
# /wiki/Papua_New_Guinea
# /wiki/Arapiraca
# /wiki/Papua_New_Guinea
# /wiki/An%C3%A1polis
# /wiki/Marion_County_Airport_(Tennessee)
# /wiki/Apucarana_Airport
# /wiki/Apple_Valley_Airport_(California)
# /wiki/Faleolo_International_Airport
# /wiki/Arapongas_Airport
# /wiki/Alto_Parna%C3%ADba
# /wiki/Zapala_Airport
# /wiki/Araraquara_Airport
# /wiki/Quich%C3%A9_Airport
# /wiki/Anqing_Tianzhushan_Airport
# /wiki/Al_Qaisumah/Hafr_Al_Batin_Airport
# /wiki/King_Hussein_International_Airport
# /wiki/Ariquemes_Airport
# /wiki/Rodr%C3%ADguez_Ball%C3%B3n_International_Airport
# /wiki/Saqani
# /wiki/Girdwood_Airport
# /wiki/Acadiana_Regional_Airport
# /wiki/Ann_Arbor_Municipal_Airport
# /wiki/Arctic_Village_Airport
# /wiki/Alor_Island_Airport
# /wiki/Antonio_(Nery)_Juarbe_Pol_Airport
# /wiki/Acaricuara
# /wiki/Walnut_Ridge_Regional_Airport
# /wiki/Talagi_Airport
# /wiki/Chacalluta_International_Airport
# /wiki/Arso_Airport
# /wiki/Arusha_Airport
# /wiki/Arly_Airport
# /wiki/Armidale_Airport
# /wiki/Stockholm_Arlanda_Airport
# /wiki/Arboletes
# /wiki/Papua_New_Guinea
# #cite_note-3
# /wiki/Alto_R%C3%ADo_Senguer_Airport
# /wiki/Aragar%C3%A7as
# /wiki/Watertown_International_Airport
# /wiki/Ara%C3%A7atuba_Airport
# /wiki/Lakeland_Airport
# /wiki/Arad_International_Airport
# /wiki/Aracati_Airport
# /wiki/Ararat_Airport
# /wiki/N%27zeto_Airport
# /wiki/Assab_International_Airport
# /wiki/Ashgabat_International_Airport
# /wiki/Ascenci%C3%B3n_de_Guarayos_Airport
# /wiki/Andros_Town_International_Airport
# /wiki/Aspen%E2%80%93Pitkin_County_Airport
# /wiki/Narimanovo_Airport
# /wiki/Ashburton_Aerodrome
# /wiki/Nashua_Airport
# /wiki/RAF_Ascension_Island
# /wiki/Amami_Airport
# /wiki/Yamoussoukro_Airport
# /wiki/Harrison_County_Airport_(Texas)
# /wiki/Asmara_International_Airport
# /wiki/Talladega_Municipal_Airport
# /wiki/Asosa_Airport
# /wiki/Alice_Springs_Airport
# /wiki/Austin_Airport_(Nevada)
# /wiki/Erkilet_International_Airport
# /wiki/Astoria_Regional_Airport
# /wiki/Silvio_Pettirossi_International_Airport
# /wiki/Amboseli_Airport
# /wiki/Aswan_International_Airport
# /wiki/John_F._Kennedy_Memorial_Airport
# /wiki/Ashley_Municipal_Airport
# /wiki/Papua_New_Guinea
# /wiki/Comandante_FAP_Germ%C3%A1n_Arias_Graziani_Airport
# /wiki/Atbara_Airport
# /wiki/Arthur%27s_Town_Airport
# /wiki/Uru_Harbour_Airport
# /wiki/Antlers_Municipal_Airport
# /wiki/Chachoan_Airport
# /wiki/PAF_Base_Minhas
# /wiki/Athens_International_Airport
# /wiki/Artigas_Airport
# /wiki/Antsirabe
# /wiki/Atqasuk_Edward_Burnell_Sr._Memorial_Airport
# /wiki/Hartsfield%E2%80%93Jackson_Atlanta_International_Airport
# /wiki/Altamira_Airport
# /wiki/Namatanai_Airport
# /wiki/Ohio_University_Airport
# /wiki/Aitape_Airport
# /wiki/Sri_Guru_Ram_Dass_Jee_International_Airport
# /wiki/Atar_International_Airport
# /wiki/Artesia_Municipal_Airport
# /wiki/Atmautluak_Airport
# /wiki/Casco_Cove_Coast_Guard_Station
# /wiki/Ati_Airport
# /wiki/Appleton_International_Airport
# /wiki/Atbasar_Airport
# /wiki/Watertown_Regional_Airport
# /wiki/Assiut_Airport
# /wiki/Queen_Beatrix_International_Airport
# /wiki/Santiago_P%C3%A9rez_Quiroz_Airport
# /wiki/Augustus_Downs_Station
# /wiki/Abu_Rudeis_Airport
# /wiki/Auxerre_%E2%80%93_Branches_Aerodrome
# /wiki/Augusta_State_Airport
# /wiki/Abu_Dhabi_International_Airport
# /wiki/Aua_Island
# /wiki/Ambunti
# /wiki/Alakanuk_Airport
# /wiki/Aur_Airport
# /wiki/Austin_Municipal_Airport
# /wiki/Auburn_Municipal_Airport_(California)
# /wiki/Auburn_University_Regional_Airport
# /wiki/Agaun_Airport
# /wiki/Atuona_Airport
# /wiki/Aurillac_%E2%80%93_Tronqui%C3%A8res_Airport
# /wiki/Austin%E2%80%93Bergstrom_International_Airport
# /wiki/Atauro_Island
# /wiki/Aurukun_Airport
# /wiki/Papua_New_Guinea
# /wiki/Wausau_Downtown_Airport
# /wiki/Aragua%C3%ADna_Airport
# /wiki/Anatom_Airport
# /wiki/Aurora_Municipal_Airport_(Illinois)
# /wiki/Anshun_Huangguoshu_Airport
# /wiki/Aviano_Air_Base
# /wiki/Auvergne_Station
# /wiki/M%C3%A1ximo_G%C3%B3mez_Airport
# /wiki/Arvaikheer_Airport
# /wiki/Asheville_Regional_Airport
# /wiki/Avignon_%E2%80%93_Provence_Airport
# /wiki/Avon_Park_Executive_Airport
# /wiki/Wilkes-Barre/Scranton_International_Airport
# /wiki/Guadalcanal_Province
# /wiki/Avalon_Airport
# /wiki/Marana_Regional_Airport
# /wiki/Catalina_Airport
# /wiki/Awasa_Airport
# /wiki/Awaba_Airport
# /wiki/Aniwa_Airport
# /wiki/Gabon
# /wiki/Wake_Island_Airfield
# /wiki/West_Memphis_Municipal_Airport
# /wiki/Alton_Downs_Airport
# /wiki/Austral_Downs
# /wiki/Awar
# /wiki/Ahvaz_International_Airport
# /wiki/Clayton_J._Lloyd_International_Airport
# /wiki/Alexandria_Bay,_New_York
# /wiki/Aramac_Airport
# /wiki/Alexandroupoli_Airport
# /wiki/Xanxer%C3%AA
# /wiki/Alxa_Left_Banner_Bayanhot_Airport
# /wiki/Algona_Municipal_Airport
# /wiki/Amakusa_Airfield
# /wiki/Ataq_Airport
# /wiki/Alexandria_Station_(Northern_Territory)
# /wiki/El_Ed%C3%A9n_International_Airport
# /wiki/Alexandria_Municipal_Airport
# /wiki/Spring_Point_Airport
# /wiki/Arutua_Airport
# /wiki/Altus/Quartz_Mountain_Regional_Airport
# /wiki/Akita_Airport
# /wiki/Axum_Airport
# /wiki/Neil_Armstrong_Airport
# /wiki/Angel_Fire_Airport
# /wiki/Ayapel_Airport
# /wiki/Colombia
# /wiki/Alroy_Downs
# /wiki/Yaguara
# /wiki/Colombia
# /wiki/Arkalyk_Airport
# /wiki/Anthony_Lagoon
# #cite_note-IATA-1
# /wiki/Anyang_Airport
# /wiki/Juan_de_Ayolas_Airport
# /wiki/Coronel_FAP_Alfredo_Mend%C3%ADvil_Duarte_Airport
# /wiki/Ayers_Rock_Airport
# /wiki/Ayr,_Queensland
# /wiki/Waycross%E2%80%93Ware_County_Airport
# /wiki/Antalya_Airport
# /wiki/Aiyura_Airport
# /wiki/Ayawasi_Airport
# /wiki/Tnte._Gral._Gerardo_P%C3%A9rez_Pinedo_Airport
# #cite_note-IATA-1
# /wiki/Phoenix%E2%80%93Mesa_Gateway_Airport
# /wiki/Amazon_Bay
# /wiki/Shahid_Sadooghi_Airport
# /wiki/Apatzing%C3%A1n
# /wiki/Al_Bateen_Executive_Airport
# #cite_note-4
# /wiki/Andizhan_Airport
# /wiki/Kalamazoo/Battle_Creek_International_Airport
# /wiki/Ciudad_L%C3%B3pez_Mateos
# /wiki/Touat-Cheikh_Sidi_Mohamed_Belkebir_Airport
# /wiki/Saman%C3%A1_El_Catey_International_Airport
# /wiki/Zapatoca
# /wiki/Ambriz_Airport

# %% [markdown]
# # Q3. [20 points]
#
# For the airports in _airports.tsv_ that you created in Q2, create a second file __airport-coordinates.tsv__ with the
# airports' geo-coordinates from the airports' Wikipedia pages.<br>
# Limit this to airports in the US state of California (based on _airports.tsv_ info).
# This will greatly limit the number of requests to the web and processing time on your computer.<br>
# Store the data in tab-separated format.<br>
# Fields: (1) IATA code (2) geo-coordinates. E.g.:
# ```
# ACV     40°58′40″N 124°06′30″W
# AHC     40°15′57″N 120°09′02″W
# APC     38°12′47.50″N 122°16′50.50″W
# ...
# ```
# As for Q2, we recommend caching the web pages on your computer and waiting a few seconds between requests.<br>
# For almost all California airports, Wikipedia lists a normal airport Wikipedia page that contains coordinates.<br>
# For the very small number of exceptions, where Wikipedia does not list a page with coordinates,
# you don't need to write anything to _airport-coordinates.tsv_, i.e.
# no need to find the coordinates elsewhere on the Web.

# %% [markdown]
# # Q4. [20 points]
#
# Define a class __GeoCoordinates__ that stores geo-coordinates in both DMS (degree/minute/second) format
# and plain latitude/longitude format. Include functions that convert between the formats. A complete
# GeoCoordinates instance will store the coordinates in both formats. For example, the geo-coordinates for USC are
# * 34°01′18″N 118°17′07″W
# * which is equivalent to a latitude of 34.02167 and a longitude of -118.28528
#
# 34°01′18″N is short for 34 degrees, 1 minute, 18 seconds north.<br>
# There are 60 minutes in a degree, and 60 seconds in a minute.<br>
# 34°01′18″ = 34 + 1/60 + 18/3600 = 34.02167<br>
# Southern latitudes and Western longitudes are expressed as negative values.<br>
#
# An instance of a new _GeoCoordinates_ can be created by either providing a DMS (of type str)
# or, alternatively, both latitude and longitude (both float).
#
# Variables for _GeoCoordinates_ should include dms (str), lat (float), long (float).<br>
# Methods for _GeoCoordinates_ should include at least \_\_init\_\_(), \_\_str\_\_(), distance().
# We provide the distance() method to you below.<br>
# You probably want to write separate functions that convert from DMS to lat/long and vice versa.

# %%
from __future__ import annotations
from math import sin, cos, sqrt, atan2, radians
from typing import Optional, Tuple

class GeoCoordinates:
    def __init__(self, lat: Optional[float] = None, long: Optional[float] = None, dms: Optional[str] = None):
        pass  # replace this line with your code
    
    def __str__(self) -> str:
        pass  # replace this line with your code
   
    def distance(self, other: GeoCoordinates) -> float:
        earth_radius = 6373.0  # in kilometers
        lat1 = radians(self.lat)
        lon1 = radians(self.long)
        lat2 = radians(other.lat)
        lon2 = radians(other.long)
        dlon = lon2 - lon1
        dlat = lat2 - lat1
        a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
        c = 2 * atan2(sqrt(a), sqrt(1 - a))
        distance = earth_radius * c
        return distance  # in kilometers

# %%
# open test
gc_la = GeoCoordinates(dms='34°03′N 118°15′W')
gc_sf = GeoCoordinates(lat=37.7775, long=-122.41639)
print('Coordinates of Los Angeles:', gc_la)
print('Coordinates of San Francisco:', gc_sf)
print(f'Straight-line distance from Los Angeles to San Francisco: {round(gc_la.distance(gc_sf))}km')

# %% [markdown]
# should print
# ```
# Coordinates of Los Angeles: 34°03′N 118°15′W (lat: 34.05, long: -118.25)
# Coordinates of San Francisco: 37°46′39″N 122°24′59″W (lat: 37.7775, long: -122.41639)
# Straight-line distance from Los Angeles to San Francisco: 559km
# ```

# %% [markdown]
# # Q5. [20 points]
#
# Define two classes _Airport_ and its subclass _GeoAirport_ for those airports that have an entry in _airport-coordinates.tsv_ (true for almost all California airports).<br>
# _Airport_ instances will have variables for at least their IATA codes, their names, and their locations.<br>
# _GeoAirport_ instances will also have variables for their geo-coordinates as well as a list of nearby airports,
# within a 100km range, technically a list of tuples (distance: float, nearby_airport: GeoAirport).<br>
# Both should have reasonable \_\_str\_\_() methods. _GeoAirport_ should also have a method show_nearby_airports() that returns
# a string with nearby airports in pretty format.<br>
#
# Define a function __load_airports()__ that will build a list or airports (Airport and GeoAirport) from the files airports.tsv and airport-coordinates.tsv that you built.
# Define a function __ais()__ (Airport Information System), which given a user request (of type str), will return airport information (one or more lines).
# Please make sure to use modular programming with meaningful functions (that have meaningful return values).
# Your program should process the following 6 formats as input for __ais()__:
#
# * ais("\<IATA-code\>")
# * ais("\<DMS-lat\> \<DMS-long\>")
# * ais("\<DMS-lat\> \<DMS-long\> \<number-of-nearest-airports\>")
# * ais("\<latitude\> \<longitude\>")
# * ais("\<latitude\> \<longitude\> \<number-of-nearest-airports\>")
# * ais("\<airport-name-substring\>")
#
# Apply the _substring_ format only if none of the above formats did not match.
# The _substring_ can be anywhere in the airport's name, incl. in the middle.
#
# ## Examples
#
# ### Example 1 (IATA code of regular Airport)
# Command:
# ```
# ais("PEK")
# ```
# Returns:
# ```
# PEK  Beijing Capital International Airport  (Beijing, China)
# ```
#
# ### Example 2 (IATA code of GeoAirport)
# Command:
# ```
# ais("LAX")
# ```
# Returns:
# ```
# LAX  Los Angeles International Airport  (Los Angeles, California, United States; 33°56′33″N 118°24′29″W)
#    Nearby:   7km HHR Hawthorne Municipal Airport (Jack Northrop Field)
#    Nearby:   9km SMO Santa Monica Municipal Airport
#    Nearby:  16km CPM Compton/Woodley Airport
#    Nearby:  17km TOA Zamperini Field
#    Nearby:  27km LGB Long Beach Airport
#    ...
#    Nearby:  92km RIR Flabob Airport
# ```
#
# ### Example 3 (substring of airport name)
#
# Command:
# ```
# ais("Oak")
# ```
# Returns:
# ```
# OAK  Oakland International Airport  (Oakland, California, United States; 37°43′17″N 122°13′15″W)
# ODC  Oakdale Airport (FAA: O27)  (Oakdale, California, United States; 37°45′23″N 120°48′01″W)
# OKY  Oakey Army Aviation Centre  (Oakey, Queensland, Australia)
# PTK  Oakland County International Airport  (Pontiac, Michigan, United States)
# ```
#
# ### Example 4 (USC coordinates, plain lat/long format, without number of nearest airports)
#
# Command:
# ```
# ais("34.02167 -118.28528")
# ```
# Returns:
# ```
#  12km HHR  Hawthorne Municipal Airport (Jack Northrop Field)  (Hawthorne, California, United States; 33°55′22″N 118°20′07″W)
# ```
#
# ### Example 5 (USC coordinates, DMS format, with number of nearest airports)
#
# Command:
# ```
# ais("34°01′18″N 118°17′07″W 4")
# ```
# Returns:
# ```
#  12km HHR  Hawthorne Municipal Airport (Jack Northrop Field)  (Hawthorne, California, United States; 33°55′22″N 118°20′07″W)
#  14km LAX  Los Angeles International Airport  (Los Angeles, California, United States; 33°56′33″N 118°24′29″W)
#  15km CPM  Compton/Woodley Airport  (Compton, California, United States; 33°53′24″N 118°14′37″W)
#  15km SMO  Santa Monica Municipal Airport  (Santa Monica, California, United States; 34°00′57″N 118°27′05″W)
# ```

# %%
def load_airports():  
    """This function loads the airport information from the files built in Q2 and Q3
    and populates class objects for Airport and GeoAirport"""
    pass  # replace this line with your code

def ais(s: str) -> str:
    return "?"  # replace this line with your code

# %%
# open test

load_airports() 

for arg in ("PEK", "LAX", "Oak", "34.02167 -118.28528", "34°01′18″N 118°17′07″W 4"):
    print (f"Input: {arg}\n{ais(arg)}\n")
